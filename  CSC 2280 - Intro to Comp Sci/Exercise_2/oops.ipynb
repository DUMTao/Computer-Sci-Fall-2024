# %%
# Broken
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('james_bond_data_cleansed.csv')
rating_data = df['imdb']

plt.title("Scatter Plot of Ratings")
plt.ylabel("Average Rotten Tomatoes Rating")
plt.xlabel("Average IMDB Rating")

plt.scatter(rating_data, df.index)

# %%
# works
x = rating_data = df['imdb']
y = bondkills_data = df['bond_kills']

plt.title("Bond Kills vs IMDb Rating")
plt.xlabel("IMDb Rating")
plt.ylabel("Bond Kills")

plt.scatter(x, y)

# %%
# not work
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('james_bond_data_cleansed.csv')
print(df.columns)

xaxis_line = moviebudget_data = df['movie_budget']
year_data = df['release_year'].astype(str)

yaxis = incomeworld_data = df['income_world']

years_labels = ['1960', '1970', '1980', '1990', '2000', '2010', '2020']

plt.figure(figsize=(10, 6))
plt.plot(year_data, xaxis_line, "-b", label="Movie Budget", marker='o')
plt.plot(yaxis, "-r", label="Income world", marker='o')

plt.legend(loc="upper left")

plt.xlabel('Release Year')


plt.show()
